# %%
print "hello"
# Out:
# hello

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np

# %%
print "hello"
# Out:
# hello

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %%
import pandas as pd
cand= pd.read_csv('C:\Users\HOME\Downloads\cand.csv')

cand.tail()

from mpl_finance import candlestick_ohlc
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import datetime as datetime
import numpy as np

# %%
fig, ax = plt.subplots()
cand.tail()
# Out:
#            Date      Open      High       Low     Close
# 2849  7/12/2018   261.40    264.50    261.15    262.75
# 2850  7/13/2018   262.10    262.40    256.80    257.75
# 2851  7/16/2018       NA        NA        NA        NA
# 2852  7/17/2018   250.70    259.85    250.45    259.05
# 2853  7/18/2018   260.10    262.50    256.15    259.55

# %%
cand = cand.dropna(thresh=5)

cand.fillna(cand.mean())
# Out:
#            Date    Open    High     Low   Close    oc     oh    ol
# 0      1/2/2007  117.94  118.88  117.28  118.28 -0.34  -0.94  0.66
# 1      1/3/2007  117.94  119.82  116.72  119.34 -1.40  -1.88  1.22
# 2      1/4/2007  119.83  120.77  116.74  117.28  2.55  -0.94  3.09
# 3      1/5/2007  117.09  118.68  116.35  117.38 -0.29  -1.59  0.74
# 4      1/8/2007  117.83  117.83  113.89  114.51  3.32   0.00  3.94
# 5      1/9/2007  115.10  115.34  110.50  110.85  4.25  -0.24  4.60
# 6     1/10/2007  110.49  110.96  106.89  107.22  3.27  -0.47  3.60
# 7     1/11/2007  108.03  109.35  106.81  108.26 -0.23  -1.32  1.22
# 8     1/12/2007  109.64  116.64  109.45  115.62 -5.98  -7.00  0.19
# 9     1/15/2007  116.53  116.53  114.08  115.32  1.21   0.00  2.45
# 10    1/16/2007  118.41  118.41  113.61  114.15  4.26   0.00  4.80
# 11    1/17/2007  115.01  116.43  114.46  115.35 -0.34  -1.42  0.55
# 12    1/18/2007  115.68  118.32  115.49  115.96 -0.28  -2.64  0.19
# ...

# %%
# Out:
# 2845

# %%
cand[['Open','Close','High','Low']] = cand[['Open','Close','High','Low']].apply(pd.to_numeric,errors='coerce')

# %%
test = cand['Open'] - cand['Close']
cand['oc']  = cand['Open'] - cand['Close']
cand['oh'] = cand['Open'] - cand['High']
cand['ol'] = cand['Open'] - cand['Low']

# %%
date = cand['Date']
op = cand['Open']
high = cand['Close']
close = cand['High']
low = cand['Low']
len(date)
# Out:
# 2845

# %%
x = 0
y = len(date)
ohlc = []

while x < y:
    append_me = cand['Date'],cand['Open'],cand['High'],cand['Close'],cand['Low']
    ohlc.append(append_me)
    x+=1

# %%
print ohlc
# Out:
# [('1/2/2007', ' 117.94 ', ' 118.88 ', ' 118.28 ', ' 117.28 '), ('1/3/2007', ' 117.94 ', ' 119.82 ', ' 119.34 ', ' 116.72 '), ('1/4/2007', ' 119.83 ', ' 120.77 ', ' 117.28 ', ' 116.74 '), ('1/5/2007', ' 117.09 ', ' 118.68 ', ' 117.38 ', ' 116.35 '), ('1/8/2007', ' 117.83 ', ' 117.83 ', ' 114.51 ', ' 113.89 '), ('1/9/2007', ' 115.10 ', ' 115.34 ', ' 110.85 ', ' 110.50 '), ('1/10/2007', ' 110.49 ', ' 110.96 ', ' 107.22 ', ' 106.89 '), ('1/11/2007', ' 108.03 ', ' 109.35 ', ' 108.26 ', ' 106.81 '), ('1/12/2007', ' 109.64 ', ' 116.64 ', ' 115.62 ', ' 109.45 '), ('1/15/2007', ' 116.53 ', ' 116.53 ', ' 115.32 ', ' 114.08 '), ('1/16/2007', ' 118.41 ', ' 118.41 ', ' 114.15 ', ' 113.61 '), ('1/17/2007', ' 115.01 ', ' 116.43 ', ' 115.35 ', ' 114.46 '), ('1/18/2007', ' 115.68 ', ' 118.32 ', ' 115.96 ', ' 115.49 '), ('1/19/2007', ' 120.98 ', ' 120.98 ', ' 115.14 ', ' 114.17 '), ('1/22/2007', ' 114.92 ', ' 116.24 ', ' 115.54 ', ' 114.92 '), ('1/23/2007', ' 115.59 ', ' 116.22 ', ' 110.77 ', ' 110.11
# ...

# %%
import matplotlib.dates as mdates
cand['Date'] = pd.to_datetime(cand['Date'])
cand["Date"] = cand["Date"].apply(mdates.date2num)
ohlc2= cand[['Date', 'Open', 'High', 'Low','Close']].copy()

# %%
date, closes, highs, lows, opens = cand['Date'].tolist(), cand['Close'].tolist(), cand['High'].tolist(),cand['Low'].tolist(), cand['Open'].tolist()
ohlc3 = [tuple([date[i],opens[i],highs[i],lows[i], closes[i]
       ]) for i in range(len(date))]

# %%
from mpl_finance import candlestick_ohlc
f1, ax = plt.subplots(figsize = (10,5))
ax1 = plt.subplot2grid((1,1),(0,0))
ohlc2= ohlc2.tail(60)
candlestick_ohlc(ax, ohlc3, width=.6, colorup='green', colordown='red')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.show()

# %%
plt.savefig('OHLC HDFC.png')

# %%
cand2 = cand[['oc','ol','oh']]

# %%
cand2
# Out:
#         oc    ol     oh
# 0    -0.34  0.66  -0.94
# 1    -1.40  1.22  -1.88
# 2     2.55  3.09  -0.94
# 3    -0.29  0.74  -1.59
# 4     3.32  3.94   0.00
# 5     4.25  4.60  -0.24
# 6     3.27  3.60  -0.47
# 7    -0.23  1.22  -1.32
# 8    -5.98  0.19  -7.00
# 9     1.21  2.45   0.00
# 10    4.26  4.80   0.00
# 11   -0.34  0.55  -1.42
# 12   -0.28  0.19  -2.64
# 13    5.84  6.81   0.00
# 14   -0.62  0.00  -1.32
# 15    4.82  5.48  -0.63
# 16    0.14  2.35  -1.04
# 17   -0.11  1.21  -0.54
# 18    3.20  3.68   0.00
# 19    2.04  2.76  -1.69
# 20   -4.25  2.10  -6.79
# 21    3.21  3.95  -0.23
# 22   -1.98  0.53  -2.92
# 23    0.80  1.39  -0.48
# 24    0.00  0.91  -0.83
# 25   -0.97  0.28  -2.26
# 26    0.60  2.54  -0.82
# 27    1.51  2.61  -0.39
# 28    0.90  2.34  -1.57
# 29    4.50  6.11  -0.94
# ...    ...   ...    ...
# 2823 -7.15  0.80  -8.40
# 2824  1.40  2.65  -1.85
# 2825 -4.05  1.95  -4.95
# 2826 -0.70  0.15  -5.10
# 2827 -8.85  0.00 -10.40
# 2828 -3.70  0.35  -5.65
# ...
